# %% [markdown]
# <a href="https://colab.research.google.com/github/esthercrismas21/Pemrograman-Dasar/blob/main/Perteman_1_2(Latihan).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Biodata Saya

nama = "Esther"
umur = 19
jurusan = "Elektro"
prodi = "TRPE"
nim = 4232501056
tinggi_badan = 160.1
semester = 3
matakuliah = 'Pemrograman Dasar'
hobi = ["Membaca, Badminton, Merajut"]
warna_favorit = ("Ungu, Biru")
status_lulus = False
alamat = "Bengkong Palapa"
departemen = "Kominfo"
asal = {
    "asal daerah: Batam",
    "suku: Batak"
}

#perintah untuk menampilkan nilai pada variabel

print(nama)
print(umur)
print(jurusan)
print(prodi)
print(nim)
print(tinggi_badan)
print(semester)
print(matakuliah)
print(", ".join(hobi))
print(warna_favorit)
print(status_lulus)
print(alamat)
print(departemen)
print(", ".join(asal))
# Out:
# Esther
# 19
# Elektro
# TRPE
# 4232501056
# 160.1
# 3
# Pemrograman Dasar
# Membaca, Badminton, Merajut
# Ungu, Biru
# False
# Bengkong Palapa
# Kominfo
# suku: Batak, asal daerah: Batam
